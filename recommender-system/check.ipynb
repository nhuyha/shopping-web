# %%
import numpy as np
import pandas as pd

# %%
book=pd.read_csv('books.csv')
book
# Out:
#     Unnamed: 0  Book_id                                              Title  \
# 0           28        1        Gods and Kings (Chronicles of the Kings #1)
# 1           66        2          Stitch 'N Bitch Crochet: The Happy Hooker
# 2           96        3  Why Men Love Bitches: From Doormat to Dreamgir...
# 3           41        4                                       Little Women
# 4           30        5                                 Great Expectations
# ..         ...      ...                                                ...
# 95          36       96                        Invisible Monsters: A Novel
# 96          15       97                                     Anyone But You
# 97          91       98                        True Believer (Large Print)
# 98          54       99                 Predator (Kay Scarpetta Mysteries)
# 99          55      100                                      Push: A Novel
#
#     Price                                        description  \
# ...

# %%
book['Price']=book["Price"]*25000
book
# Out:
#     Unnamed: 0  Book_id                                              Title  \
# 0           28        1        Gods and Kings (Chronicles of the Kings #1)
# 1           66        2          Stitch 'N Bitch Crochet: The Happy Hooker
# 2           96        3  Why Men Love Bitches: From Doormat to Dreamgir...
# 3           41        4                                       Little Women
# 4           30        5                                 Great Expectations
# ..         ...      ...                                                ...
# 95          36       96                        Invisible Monsters: A Novel
# 96          15       97                                     Anyone But You
# 97          91       98                        True Believer (Large Print)
# 98          54       99                 Predator (Kay Scarpetta Mysteries)
# 99          55      100                                      Push: A Novel
#
#        Price                                        description  \
# ...

# %%
book=book[['Book_id','Title','Price','description','authors','image']]
book
# Out:
#     Book_id                                              Title     Price  \
# 0         1        Gods and Kings (Chronicles of the Kings #1)  254750.0
# 1         2          Stitch 'N Bitch Crochet: The Happy Hooker  271250.0
# 2         3  Why Men Love Bitches: From Doormat to Dreamgir...  271250.0
# 3         4                                       Little Women  474750.0
# 4         5                                 Great Expectations  573750.0
# ..      ...                                                ...       ...
# 95       96                        Invisible Monsters: A Novel  254250.0
# 96       97                                     Anyone But You  981250.0
# 97       98                        True Believer (Large Print)  900000.0
# 98       99                 Predator (Kay Scarpetta Mysteries)  176000.0
# 99      100                                      Push: A Novel  176500.0
#
#                                           description  \
# ...

# %%
book.to_csv("books.csv")
